# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_csv ('energydata_complete.csv')
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %% [raw]
# # Data Dictionary
# date - Date and time of the observation
# Appliances - Energy consumption of appliances in the house (in Wh)
# lights - Energy consumption of lights in the house (in Wh)
# T1 - Temperature in room 1 (in Celsius)
# RH_1 - Humidity in room 1 (in %)
# T2 - Temperature in room 2 (in Celsius)
# RH_2 - Humidity in room 2 (in %)
# T3 - Temperature in room 3 (in Celsius)
# RH_3 - Humidity in room 3 (in %)
# T4 - Temperature in room 4 (in Celsius)
# RH_4 - Humidity in room 4 (in %)
# T5 - Temperature in room 5 (in Celsius)
# RH_5 - Humidity in room 5 (in %)
# T6 - Temperature outside the building (north side, in Celsius)
# RH_6 - Humidity outside the building (north side, in %)
# T7 - Temperature in ironing room (in Celsius)
# RH_7 - Humidity in ironing room (in %)
# T8 - Temperature in teenager room 1 (in Celsius)
# RH_8 - Humidity in teenager room 1 (in %)
# T9 - Temperature in teenager room 2 (in Celsius)
# RH_9 - Humidity in teenager room 2 (in %)
# T_out - Temperature outside (from Chievres weather station, in Celsius)
# Press_mm_hg - Pressure (from Chievres weather station, in mm Hg)
# RH_out - Humidity outside (from Chievres weather station, in %)
# Windspeed - Windspeed (from Chievres weather station, in m/s)
# Visibility - Visibility (from Chievres weather station, in km)
# Tdewpoint - Dew point temperature (from Chievres weather station, in Celsius)
# rv1 - Random variable 1 (uniformly distributed, no unit)
# rv2 - Random variable 2 (uniformly distributed, no unit)

# %%
df.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
df.shape
# Out:
# (19735, 29)

# %%
df.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Histogram of Appliances energy consumption
plt.figure(figsize=(8, 6))
sns.histplot(df['Appliances'], bins=30, kde=True)
plt.title('Distribution of Appliances Energy Consumption')
plt.xlabel('Energy Consumption (Wh)')
plt.ylabel('Frequency')
plt.show()

# %%
# Line plot of energy consumption over time
plt.figure(figsize=(12, 6))
sns.lineplot(x='date', y='Appliances', data=df)
plt.title('Energy Consumption Over Time')
plt.xlabel('Date')
plt.ylabel('Energy Consumption (Wh)')
plt.show()

# %%
# Question 17
df2 = df.drop(columns=['date'])

X = df2['T2'].values.reshape(-1,1) # reshape to 2D array
y = df2['T6']

# %%
model = LinearRegression()
model.fit(X, y)

# Making predictions
y_pred = model.predict(X)

# %%
# Calculating RMSE
rmse = np.sqrt(mean_squared_error(y, y_pred))
round(rmse, 3)
# Out:
# 3.644

# %%
#18
df3 = df.drop(columns=['date', 'lights'])
df3.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40  6.133333        733.9    92.0
#
# ...

# %%
X = df3.drop(columns=['Appliances'])
y = df3['Appliances']

# %%
# Split the data into train and test sets
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Scale the features using MinMaxScaler
scaler = MinMaxScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
# Creating and fitting the model
model = LinearRegression()
model.fit(x_train_scaled, y_train)

# Making predictions on the training set
y_train_pred = model.predict(x_train_scaled)

# Calculating MAE for the training set
mae_train = mean_absolute_error(y_train, y_train_pred)
round(mae_train, 3)
# Out:
# 53.742

# %%
#19
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
round(rmse_train, 3)
# Out:
# 95.216

# %%
#20
# Obtain predictions on the test set
predicted_values_scaled = model.predict(x_test_scaled)

mae = mean_absolute_error(y_test, predicted_values_scaled)
round(mae, 3)
# Out:
# 53.643

# %%
#21
rmse = np.sqrt(mean_squared_error(y_test, predicted_values_scaled))
round(rmse, 3)
# Out:
# 93.64

# %% [markdown]
# #22
# - No

# %%
#23
ridge_reg = Ridge()
ridge_reg.fit(x_train_scaled, y_train)

# Make predictions on the test set
y_test_pred_ridge = ridge_reg.predict(x_test_scaled)

# Calculate RMSE for the test set
rmse_ridge = np.sqrt(mean_squared_error(y_test, y_test_pred_ridge))
round(rmse_ridge, 3)
# Out:
# 93.709

# %%
#24
lasso_reg = Lasso()
lasso_reg.fit(x_train_scaled, y_train)


def get_weights_df(model, feat, col_name)

  weights = pd.Series(model.coef_, feat.columns).sort_values()
  weights_df = pd.DataFrame(weights).reset_index()
  weights_df.columns = ['Features', col_name]
  weights_df[col_name].round(3)
  return weights_df

linear_model_weights = get_weights_df(model, x_train, 'Linear_Model_Weight')
ridge_weights_df = get_weights_df(ridge_reg, x_train, 'Ridge_Weight')
lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')

final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on='Features')
final_weights
# Out:
#        Features  Linear_Model_Weight  Ridge_Weight  Lasso_weight
# 0          RH_2          -469.521362   -380.264856     -0.000000
# 1         T_out          -344.389845   -220.546136      0.000000
# 2            T2          -252.710373   -181.115240      0.000000
# 3            T9          -203.236627   -198.646042     -0.000000
# 4          RH_8          -168.627161   -166.246807    -26.102888
# 5        RH_out           -83.107599    -36.798983    -50.293976
# 6          RH_7           -47.563552    -50.215392     -0.000000
# 7          RH_9           -42.586339    -45.543329     -0.000000
# 8            T5           -16.752822    -25.703802     -0.000000
# 9            T1            -3.510725    -32.142710      0.000000
# 10          rv2             0.823870      0.775954     -0.000000
# 11          rv1             0.823870      0.775954     -0.000000
# 12  Press_mm_hg             7.315243      6.767363     -0.000000
# ...

# %% [markdown]
# # 4 to 5 features

# %%
#25
y_test_pred_lasso = lasso_reg.predict(x_test_scaled)
rmse_lasso = np.sqrt(mean_squared_error(y_test, y_test_pred_lasso))
round(rmse_lasso, 3)
# Out:
# 99.424
